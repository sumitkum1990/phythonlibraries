# %%
import pandas as pd
import numpy as np

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
pd.read_json(url)
import requests
data= requests.get(url)

df = data.json()

# %%
data
# Out:
# <Response [200]>

# %%
df
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57241',
#   'id': 2116847445,
#   'node_id': 'PR_kwDOAA0YD85l7yjQ',
#   'number': 57241,
#   'title': 'DEPR: Remove sql.execute, *args/**kwargs in resample, unrecognized timezones',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
# ...

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
len(df)
# Out:
# 30

# %%
for i in range(len(df)):
  print(df[i])
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57241/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57241', 'id': 2116847445, 'node_id': 'PR_kwDOAA0YD85l7yjQ', 'number': 57241, 'title': 'DEPR: Remove sql.execute, *args/**kwargs in resample, unrecognized timezones', 'user': {'login': 'mroeschke', 'id': 10647082, 'node_id': 'MDQ6VXNlcjEwNjQ3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mroeschke', 'html_url': 'https://github.com/mroeschke', 'followers_url': 'https://api.github.com/users/mroeschke/followers', 'following_url': 'https://api.github.com/u
# ...

# %%
for i in range(len(df)):
  print(df[i]['user'])
# Out:
# {'login': 'mroeschke', 'id': 10647082, 'node_id': 'MDQ6VXNlcjEwNjQ3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mroeschke', 'html_url': 'https://github.com/mroeschke', 'followers_url': 'https://api.github.com/users/mroeschke/followers', 'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}', 'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions', 'organizations_url': 'https://api.github.com/users/mroeschke/orgs', 'repos_url': 'https://api.github.com/users/mroeschke/repos', 'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mroeschke/received_events', 'type': 'User', 'site_admin': False}
# ...

# %%
for i in range(len(df)):
  print(df[i]['user']['node_id'])
# Out:
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjc5ODk3OTg=
# MDQ6VXNlcjMzOTk5MzI1
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjEwNjQ3MDgy
# U_kgDOCMI7PA
# MDQ6VXNlcjYxMjU4MzIz
# MDQ6VXNlcjU2MDg4ODUx
# MDQ6VXNlcjExMDAwMzU0
# MDQ6VXNlcjExNzU4NTcx
# MDQ6VXNlcjM0NzM5MjE=
# U_kgDOBmdpUw
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjE5NTMzODI=
# MDQ6VXNlcjQxNzM1MzEx
# MDQ6VXNlcjc5MTIyODk=
# MDQ6VXNlcjQ3MDMyNTYz
# MDQ6VXNlcjU2OTE0ODIw
# MDQ6VXNlcjgyOTYzMzE=
# MDQ6VXNlcjE5NDc3ODY0
# MDQ6VXNlcjIyMzg1Mzcx
# MDQ6VXNlcjI1MjAzNjU1
# MDQ6VXNlcjI1MjAzNjU1
# U_kgDOCLOEtQ
# MDQ6VXNlcjI4MzM4MzY=
# MDQ6VXNlcjg0MzExNTk=
# MDQ6VXNlcjMzNDkxNjMy
# MDQ6VXNlcjg1MTk1MjM=

# %%
for i in range(len(df)):
  print(df[i]['user']['avatar_url'])
# Out:
# https://avatars.githubusercontent.com/u/10647082?v=4
# https://avatars.githubusercontent.com/u/35613487?v=4
# https://avatars.githubusercontent.com/u/7989798?v=4
# https://avatars.githubusercontent.com/u/33999325?v=4
# https://avatars.githubusercontent.com/u/61934744?v=4
# https://avatars.githubusercontent.com/u/10647082?v=4
# https://avatars.githubusercontent.com/u/146946876?v=4
# https://avatars.githubusercontent.com/u/61258323?v=4
# https://avatars.githubusercontent.com/u/56088851?v=4
# https://avatars.githubusercontent.com/u/11000354?v=4
# https://avatars.githubusercontent.com/u/11758571?v=4
# https://avatars.githubusercontent.com/u/3473921?v=4
# https://avatars.githubusercontent.com/u/107440467?v=4
# https://avatars.githubusercontent.com/u/61934744?v=4
# https://avatars.githubusercontent.com/u/10647082?v=4
# https://avatars.githubusercontent.com/u/1953382?v=4
# https://avatars.githubusercontent.com/u/41735311?v=4
# https://avatars.githubusercontent.com/u/7912289?v=4
# ...

# %%
pd.DataFrame(df, columns =['user','timeline_url'])
# Out:
#                                                  user  \
# 0   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 1   {'login': 'jordan-d-murphy', 'id': 35613487, '...
# 2   {'login': 'noah-asing', 'id': 7989798, 'node_i...
# 3   {'login': 'jrmylow', 'id': 33999325, 'node_id'...
# 4   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 5   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 6   {'login': 'koushik-rout-samsung', 'id': 146946...
# 7   {'login': 'LakshmanKishore', 'id': 61258323, '...
# 8   {'login': 'Jorewin', 'id': 56088851, 'node_id'...
# 9   {'login': 'gsehrlich', 'id': 11000354, 'node_i...
# 10  {'login': 'khider', 'id': 11758571, 'node_id':...
# 11  {'login': 'michaelquinn32', 'id': 3473921, 'no...
# 12  {'login': 'sfc-gh-aalam', 'id': 107440467, 'no...
# 13  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 14  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 15  {'login': 'steppi', 'id': 1953382, 'node_id': ...
# ...

# %%
df = pd.DataFrame(df, columns =['user','timeline_url'])

df.to_csv('json_info.csv')

# %%
#Solving the Dataset

df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#         sex embarked   class    who deck  embark_town alive
# 0      male        S   Third    man  NaN  Southampton    no
# 1    female        C   First  woman    C    Cherbourg   yes
# 2    female        S   Third  woman  NaN  Southampton   yes
# 3    female        S   First  woman    C  Southampton   yes
# 4      male        S   Third    man  NaN  Southampton    no
# ..      ...      ...     ...    ...  ...          ...   ...
# 886    male        S  Second    man  NaN  Southampton    no
# 887  female        S   First  woman    B  Southampton   yes
# 888  female        S   Third  woman  NaN  Southampton    no
# 889    male        C   First    man    C    Cherbourg   yes
# 890    male        Q   Third    man  NaN   Queenstown    no
#
# [891 rows x 7 columns]

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# sex            object
# embarked       object
# class          object
# who            object
# deck           object
# embark_town    object
# alive          object
# dtype: object

# %%
df[df.dtypes[df.dtypes != 'object'].index]
# Out:
#      survived  pclass   age  sibsp  parch     fare  adult_male  alone
# 0           0       3  22.0      1      0   7.2500        True  False
# 1           1       1  38.0      1      0  71.2833       False  False
# 2           1       3  26.0      0      0   7.9250       False   True
# 3           1       1  35.0      1      0  53.1000       False  False
# 4           0       3  35.0      0      0   8.0500        True   True
# ..        ...     ...   ...    ...    ...      ...         ...    ...
# 886         0       2  27.0      0      0  13.0000        True   True
# 887         1       1  19.0      0      0  30.0000       False   True
# 888         0       3   NaN      1      2  23.4500       False  False
# 889         1       1  26.0      0      0  30.0000        True   True
# 890         0       3  32.0      0      0   7.7500        True   True
#
# [891 rows x 8 columns]

# %%
df[df.dtypes[df.dtypes != 'object'].index].describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#          sex embarked  class  who deck  embark_town alive
# count    891      889    891  891  203          889   891
# unique     2        3      3    3    7            3     2
# top     male        S  Third  man    C  Southampton    no
# freq     577      644    491  537   59          644   549

# %%
df.describe(include = 'object')
# Out:
#          sex embarked  class  who deck  embark_town alive
# count    891      889    891  891  203          889   891
# unique     2        3      3    3    7            3     2
# top     male        S  Third  man    C  Southampton    no
# freq     577      644    491  537   59          644   549

# %%
df.describe(include = 'all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
df.astype('object').describe()
# Out:
#         survived  pclass   sex    age  sibsp  parch    fare embarked  class  \
# count        891     891   891  714.0    891    891  891.00      889    891
# unique         2       3     2   88.0      7      7  248.00        3      3
# top            0       3  male   24.0      0      0    8.05        S  Third
# freq         549     491   577   30.0    608    678   43.00      644    491
#
#         who adult_male deck  embark_town alive alone
# count   891        891  203          889   891   891
# unique    3          2    7            3     2     2
# top     man       True    C  Southampton    no  True
# freq    537        537   59          644   549   537

# %%
#df.numeric.describe()

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['new_col'] ='Sumit'

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df['family']=df['adult_male']+df['age']

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df['family']
# Out:
# 0      23.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      36.0
#        ...
# 886    28.0
# 887    19.0
# 888     NaN
# 889    27.0
# 890    33.0
# Name: family, Length: 891, dtype: float64

# %%
#pd.Categorical
df['Cabin'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cabin'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
#Q: How many passengers are less than 5 years old

df['age']<5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
df[df['age']<5]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 63          0       3    male  4.00      3      2   27.9000        S   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 171         0       3    male  4.00      4      1   29.1250        Q   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %%
len(df[df['age']>5])
# Out:
# 670

# %%
len(df[df['age']>18])
# Out:
# 575

# %%
#passenger less than 18

len(df[df['age']<18])
# Out:
# 113

# %%
len(df)- len(df[df['age']>18])
# Out:
# 316

# %%
#How many passenger paid less than Avg fare
#firt calculate AVg fare

df.describe().mean()
# Out:
# survived    111.733804
# pclass      113.268089
# age         115.596327
# sibsp       112.703219
# parch       112.273456
# fare        192.323930
# family      116.171280
# dtype: float64

# %%
df['fare'].mean()
# Out:
# 32.204207968574636

# %%
df[df['fare']<df['fare'].mean()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
len(df[df['fare']<df['fare'].mean()])
# Out:
# 680

# %%
#How many paid fare =0

len(df[df['fare']==0].Name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-2b68fcd67ace> in <cell line: 3>()
#       1 #How many paid fare =0
#       2
# ----> 3 len(df[df['fare']==0].Name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Name'

# %%
df['sex'] ==  "male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
len(df[df['sex'] ==  "male"])
# Out:
# 577

# %%
df['sex'].value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: sex, dtype: float64

# %%
len(df[df['sex'] ==  "female"])
# Out:
# 314

# %%
#Q  How many of class1

# %%
len(df[df['class'] ==  "First"])
# Out:
# 216

# %%
df['survived'].value_counts(normalize = True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: survived, dtype: float64

# %%
#How many female paid more than AVG fare

# %%
(df[df['sex'] ==  "female"])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
# ...

# %%
df['fare'].mean()
# Out:
# 32.204207968574636

# %%
df[(df['sex'] == 'female') & (df['fare']<df['fare'].mean())]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
# ...

# %%
# Q How many male passenger or paid more than AVg fare
df[(df['sex'] == 'male') | (df['fare']<df['fare'].mean())]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# Q How many male passenger paid more than AVg fare
df[(df['sex'] == 'male') & (df['fare']<df['fare'].mean())]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone new_col  family
# ...

# %%
max(df['fare'])
# Out:
# 512.3292

# %%
min(df['fare'])
# Out:
# 0.0

# %%
#Who are passengers who paid maximum fare

df[df['fare']== max(df['fare'])]['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# Access df rows
df[0:100]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 95         0       3    male   NaN      0      0   8.0500        S   Third
# 96         0       1    male  71.0      0      0  34.6542        C   First
# 97         1       1    male  23.0      0      1  63.3583        C   First
# 98         1       2  female  34.0      0      1  23.0000        S  Second
# 99         0       2    male  34.0      1      0  26.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone new_col  family
# ...

# %%
df[0:100:2]#even
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.00      1      0    7.2500        S   Third
# 2          1       3  female  26.00      0      0    7.9250        S   Third
# 4          0       3    male  35.00      0      0    8.0500        S   Third
# 6          0       1    male  54.00      0      0   51.8625        S   First
# 8          1       3  female  27.00      0      2   11.1333        S   Third
# 10         1       3  female   4.00      1      1   16.7000        S   Third
# 12         0       3    male  20.00      0      0    8.0500        S   Third
# 14         0       3  female  14.00      0      0    7.8542        S   Third
# 16         0       3    male   2.00      4      1   29.1250        Q   Third
# 18         0       3  female  31.00      1      0   18.0000        S   Third
# 20         0       2    male  35.00      0      0   26.0000        S  Second
# ...

# %%
#Implicit index and explicit index

#Implicit index : intenral index by Pandas

#explicit index: customize by us

df.iloc[0:2] # start from 0 and go to 1
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone new_col  family
# 0    man        True  NaN  Southampton    no  False   Sumit    23.0
# 1  woman       False    C    Cherbourg   yes  False   Sumit    38.0

# %%
df.loc[0:2] # give me name of the rows whose name 0,1,2
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone new_col  family
# 0    man        True  NaN  Southampton    no  False   Sumit    23.0
# 1  woman       False    C    Cherbourg   yes  False   Sumit    38.0
# 2  woman       False  NaN  Southampton   yes   True   Sumit    26.0

# %%
#loc will go with named index
#iloc go with inbuilt index

# %%
df.iloc[0:2,['Name','Sex','Age']]

# %%
df.loc[0:2,['sex','age']]
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0

# %%
df.iloc[0:2, 3:5]
# Out:
#     age  sibsp
# 0  22.0      1
# 1  38.0      1

# %%
len(df['age'][2:4])
# Out:
# 2

# %%
df['age'][2:4]
# Out:
# 2    26.0
# 3    35.0
# Name: age, dtype: float64

# %%
pd.Series(list(df['class'][2:5]), index = ['a','b','c'])
# Out:
# a    Third
# b    First
# c    Third
# dtype: object

# %%
s1 = pd.Series(list(df['class'][2:5]), index = ['a','b','c'])

# %%
s2=  pd.Series(list(df['class'][2:5]))

# %%
s2
# Out:
# 0    Third
# 1    First
# 2    Third
# dtype: object

# %%
s1+s2 # series and dataframe doesnot work with +
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
s1.append(s2)
# Out:
# <ipython-input-120-8fc823ac192a>:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s1.append(s2)
# a    Third
# b    First
# c    Third
# 0    Third
# 1    First
# 2    Third
# dtype: object

# %%
df.drop('pclass', axis =1)
# Out:
#      survived     sex   age  sibsp  parch     fare embarked   class    who  \
# 0           0    male  22.0      1      0   7.2500        S   Third    man
# 1           1  female  38.0      1      0  71.2833        C   First  woman
# 2           1  female  26.0      0      0   7.9250        S   Third  woman
# 3           1  female  35.0      1      0  53.1000        S   First  woman
# 4           0    male  35.0      0      0   8.0500        S   Third    man
# ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886         0    male  27.0      0      0  13.0000        S  Second    man
# 887         1  female  19.0      0      0  30.0000        S   First  woman
# 888         0  female   NaN      1      2  23.4500        S   Third  woman
# 889         1    male  26.0      0      0  30.0000        C   First    man
# 890         0    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone new_col  family
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.drop(1, inplace =True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.set_index('age') # used in Time series where we make Date, Time as  colum
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked   class    who  \
# age
# 22.0         0       3    male      1      0   7.2500        S   Third    man
# 26.0         1       3  female      0      0   7.9250        S   Third  woman
# 35.0         1       1  female      1      0  53.1000        S   First  woman
# 35.0         0       3    male      0      0   8.0500        S   Third    man
# NaN          0       3    male      0      0   8.4583        Q   Third    man
# ...        ...     ...     ...    ...    ...      ...      ...     ...    ...
# 27.0         0       2    male      0      0  13.0000        S  Second    man
# 19.0         1       1  female      0      0  30.0000        S   First  woman
# NaN          0       3  female      1      2  23.4500        S   Third  woman
# 26.0         1       1    male      0      0  30.0000        C   First    man
# 32.0         0       3    male      0      0   7.7500        Q   Third    man
#
# ...

# %%
df.loc[22]
# Out:
# survived                1
# pclass                  3
# sex                female
# age                  15.0
# sibsp                   0
# parch                   0
# fare               8.0292
# embarked                Q
# class               Third
# who                 child
# adult_male          False
# deck                  NaN
# embark_town    Queenstown
# alive                 yes
# alone                True
# new_col             Sumit
# family               15.0
# Name: 22, dtype: object

# %%
df.iloc[3]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   35.0
# sibsp                    0
# parch                    0
# fare                  8.05
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# new_col              Sumit
# family                36.0
# Name: 4, dtype: object

# %%
df.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        2         1       3  female  26.0      0      0   7.9250        S
# 2        3         1       1  female  35.0      1      0  53.1000        S
# 3        4         0       3    male  35.0      0      0   8.0500        S
# 4        5         0       3    male   NaN      0      0   8.4583        Q
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 885    886         0       2    male  27.0      0      0  13.0000        S
# 886    887         1       1  female  19.0      0      0  30.0000        S
# 887    888         0       3  female   NaN      1      2  23.4500        S
# 888    889         1       1    male  26.0      0      0  30.0000        C
# 889    890         0       3    male  32.0      0      0   7.7500        Q
#
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
#make DataFrame using Dictionary
d = {"key1":[2,3,4,5],
     "key2":[4,5,6,7],
     "key3": [2,3,5,6]}

# %%
d
# Out:
# {'key1': [2, 3, 4, 5], 'key2': [4, 5, 6, 7], 'key3': [2, 3, 5, 6]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     5
# 3     5     7     6

# %%
#make DataFrame using Tuple
d = {"key1":(2,3,4,5),
     "key2":(4,5,6,7),
     "key3": (2,3,5,6)}

# %%
d
# Out:
# {'key1': (2, 3, 4, 5), 'key2': (4, 5, 6, 7), 'key3': (2, 3, 5, 6)}

# %%
df1 = pd.read("D:\PWSkills\Data\taxonomy.csv.xls")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-57a23d6182ca> in <cell line: 1>()
# ----> 1 df1 = pd.read("D:\PWSkills\Data\taxonomy.csv.xls")
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df2= pd.read_csv("taxonomy.csv.xls")

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2.dropna(axis= 1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2[['name'].dropna(axis= 1)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-6663f588fd07> in <cell line: 1>()
# ----> 1 df2[['name'].dropna(axis= 1)]
#
# AttributeError: 'list' object has no attribute 'dropna'

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.fillna("missing_vale_here>laa")
# Out:
#     taxonomy_id                          name              parent_id  \
# 0           101                     Emergency  missing_vale_here>laa
# 1        101-01             Disaster Response                    101
# 2        101-02                Emergency Cash                    101
# 3     101-02-01             Help Pay for Food                 101-02
# 4     101-02-02       Help Pay for Healthcare                 101-02
# ..          ...                           ...                    ...
# 285   111-01-07              Workplace Rights                 111-01
# 286      111-02                     Mediation                    111
# 287      111-03                        Notary                    111
# 288      111-04                Representation                    111
# 289      111-05  Translation & Interpretation                    111
#
#                parent_name
# 0    missing_vale_here>laa
# 1                Emergency
# 2                Emergency
# ...

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# Q Whatis the Avg fare paid by people who survived

df.groupby('survived').mean()
# Out:
# <ipython-input-157-65c174e480fe>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('survived').mean()
#             pclass        age     sibsp     parch       fare  adult_male  \
# survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887    0.817851
# 1         1.953079  28.310277  0.472141  0.466276  48.328288    0.258065
#
#              alone     family
# survived
# 0         0.681239  31.430425
# 1         0.478006  28.559412

# %%
df.groupby('survived').max()
# Out:
# <ipython-input-158-b52252fe5791>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby('survived').max()
#           pclass   sex   age  sibsp  parch      fare  class    who  \
# survived
# 0              3  male  74.0      8      6  263.0000  Third  woman
# 1              3  male  80.0      4      5  512.3292  Third  woman
#
#           adult_male alive  alone new_col  family
# survived
# 0               True    no   True   Sumit    75.0
# 1               True   yes   True   Sumit    81.0

# %%
df.groupby('survived').min()
# Out:
# <ipython-input-159-07b7e76dd293>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df.groupby('survived').min()
#           pclass     sex   age  sibsp  parch  fare  class    who  adult_male  \
# survived
# 0              1  female  1.00      0      0   0.0  First  child       False
# 1              1  female  0.42      0      0   0.0  First  child       False
#
#          alive  alone new_col  family
# survived
# 0           no  False   Sumit    1.00
# 1          yes  False   Sumit    0.42

# %%
df.groupby('survived').sum()
# Out:
# <ipython-input-160-34795893bcc0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('survived').sum()
#           pclass       age  sibsp  parch        fare  adult_male  alone  \
# survived
# 0           1390  12985.50    304    181  12142.7199         449    374
# 1            666   8181.67    161    159  16479.9461          88    163
#
#             family
# survived
# 0         13326.50
# 1          8253.67

# %%
df.groupby('survived').describe()
# Out:
#          pclass                                                 age  \
#           count      mean       std  min  25%  50%  75%  max  count
# survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         341.0  1.953079  0.863047  1.0  1.0  2.0  3.0  3.0  289.0
#
#                      ...  fare           family                              \
#                mean  ...   75%       max  count       mean        std   min
# survived             ...
# 0         30.626179  ...  26.0  263.0000  424.0  31.430425  14.311107  1.00
# 1         28.310277  ...  57.0  512.3292  289.0  28.559412  15.068163  0.42
#
#
#            25%   50%   75%   max
# survived
# 0         22.0  29.0  40.0  75.0
# 1         19.0  28.0  37.0  81.0
#
# [2 rows x 48 columns]

# %%
df.groupby('survived').aggregate(['min','max','mean','median','std','count','var'])
# Out:
# <ipython-input-164-b08fbb2966da>:1: FutureWarning: ['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive', 'new_col'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('survived').aggregate(['min','max','mean','median','std','count','var'])
#          pclass                                                  age        \
#             min max      mean median       std count       var   min   max
# survived
# 0             1   3  2.531876    3.0  0.735805   549  0.541409  1.00  74.0
# 1             1   3  1.953079    2.0  0.863047   341  0.744851  0.42  80.0
#
#                      ...     alone                 family                   \
#                mean  ...       std count       var    min   max       mean
# survived             ...
# 0         30.626179  ...  0.466421   549  0.217549   1.00  75.0  31.430425
# ...

# %%
#groupby with 2 columns

# %%
# Q people survied for each sex, pclass

df.groupby(['sex','pclass'])['survived'].mean()
# Out:
# sex     pclass
# female  1         0.967742
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
df.groupby(['sex','pclass'])['survived'].sum()
# Out:
# sex     pclass
# female  1         90
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: survived, dtype: int64
